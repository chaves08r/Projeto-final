# %%
#Importando as bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %% [markdown]
# ## Parte 1 - Dataset State of Data 2021

# %%
import zipfile

# Caminho para o arquivo ZIP
zip_path = '../datasets/state_of_data_2021.zip'

# Nome do arquivo CSV dentro do ZIP
csv_filename = 'State of Data 2021 - Dataset - Pgina1.csv'

# Abrir o arquivo ZIP
with zipfile.ZipFile(zip_path, 'r') as z:
    # Ler o arquivo CSV diretamente do ZIP
    with z.open(csv_filename) as f:
        df_data_2021 = pd.read_csv(f)

# Exibir as primeiras linhas do DataFrame para confirmar
print(df_data_2021.head())
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s                38.0
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt                39.0
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh                30.0
# 3  v31ab41botodnsv31zgg4k34zzojy81l                38.0
# 4  ubhu8ntvm4xc0sfkdubhu80e973eek0k                36.0
#
#   ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                      35-39           Masculino
# 1                      35-39           Masculino
# 2                      30-34           Masculino
# 3                      35-39            Feminino
# 4                      35-39           Masculino
#
#   ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                    Ceará (CE)                          CE
# 1                    Bahia (BA)                          BA
# 2           Santa Catarina (SC)                          SC
# 3                São Paulo (SP)                          SP
# ...

# %%
#visulizando o nome de todas as colunas
for column in df_data_2021.columns:
    print(column)
# Out:
# ('P0', 'id')
# ('P1_a ', 'Idade')
# ('P1_a_a ', 'Faixa idade')
# ('P1_b ', 'Genero')
# ('P1_e ', 'Estado onde mora')
# ('P1_e_a ', 'uf onde mora')
# ('P1_e_b ', 'Regiao onde mora')
# ('P1_g_b ', 'Regiao de origem')
# ('P1_g_c ', 'Mudou de Estado?')
# ('P1_h ', 'Nivel de Ensino')
# ('P1_i ', 'Área de Formação')
# ('P2_a ', 'Qual sua situação atual de trabalho?')
# ('P2_b ', 'Setor')
# ('P2_c ', 'Numero de Funcionarios')
# ('P2_d ', 'Gestor?')
# ('P2_e ', 'Cargo como Gestor')
# ('P2_f ', 'Cargo Atual')
# ('P2_g ', 'Nivel')
# ('P2_h ', 'Faixa salarial')
# ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')
# ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')
# ('P2_k ', 'Você está satisfeito na sua empresa atual?')
# ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')
# ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')
# ...

# %%
def renameColumn(column):
    parts = column.split('\'')
    parts[3] = parts[3].replace(' ', '_')
    parts[3] = parts[3].replace('?', '')
    return parts[3]

df_data_2021.columns = df_data_2021.columns.map(renameColumn)

df_data_2021.head()
# Out:
#                                  id  Idade Faixa_idade     Genero  \
# 0  qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s   38.0       35-39  Masculino
# 1  zdl2n19yhgpnoaco6kkczdl2nwv9zwrt   39.0       35-39  Masculino
# 2  vsamqp2un3q7us84mgvsams5fulsmcoh   30.0       30-34  Masculino
# 3  v31ab41botodnsv31zgg4k34zzojy81l   38.0       35-39   Feminino
# 4  ubhu8ntvm4xc0sfkdubhu80e973eek0k   36.0       35-39  Masculino
#
#       Estado_onde_mora uf_onde_mora Regiao_onde_mora Regiao_de_origem  \
# 0           Ceará (CE)           CE         Nordeste              NaN
# 1           Bahia (BA)           BA         Nordeste          Sudeste
# 2  Santa Catarina (SC)           SC              Sul              NaN
# 3       São Paulo (SP)           SP          Sudeste              NaN
# 4  Santa Catarina (SC)           SC              Sul              NaN
#
#    Mudou_de_Estado Nivel_de_Ensino  ...  \
# 0                0   Pós-graduação  ...
# 1                1   Pós-graduação  ...
# ...

# %%
#visulizando o nome de todas as colunas
for column in df_data_2021.columns:
    print(column)
# Out:
# id
# Idade
# Faixa_idade
# Genero
# Estado_onde_mora
# uf_onde_mora
# Regiao_onde_mora
# Regiao_de_origem
# Mudou_de_Estado
# Nivel_de_Ensino
# Área_de_Formação
# Qual_sua_situação_atual_de_trabalho
# Setor
# Numero_de_Funcionarios
# Gestor
# Cargo_como_Gestor
# Cargo_Atual
# Nivel
# Faixa_salarial
# Quanto_tempo_de_experiência_na_área_de_dados_você_tem
# Quanto_tempo_de_experiência_na_área_de_TI/Engenharia_de_Software_você_teve_antes_de_começar_a_trabalhar_na_área_de_dados
# Você_está_satisfeito_na_sua_empresa_atual
# Qual_o_principal_motivo_da_sua_insatisfação_com_a_empresa_atual
# Falta_de_oportunidade_de_crescimento_no_emprego_atual
# Salário_atual_não_corresponde_ao_mercado
# Não_tenho_uma_boa_relação_com_meu_líder/gestor
# Gostaria_de_trabalhar_em_em_outra_área_de_atuação
# Gostaria_de_receber_mais_benefícios
# O_clima_de_trabalho/ambiente_não_é_bom
# Falta_de_maturidade_analítica_na_empresa
# Você_participou_de_entrevistas_de_emprego_nos_últimos_6_meses
# ...

# %%
#selecionando as colunas de uso
columns_to_use2 = [
    'id',
    'Idade',
    'Genero',
    'Faixa_idade',
    'Estado_onde_mora',
    'uf_onde_mora',
    'Nivel_de_Ensino',
    'Área_de_Formação',
    'Qual_sua_situação_atual_de_trabalho',
    'Nivel',
    'Faixa_salarial'

]

# %%
df_data_2021 = df_data_2021[columns_to_use2]
print(df_data_2021)
# Out:
#                                     id  Idade     Genero Faixa_idade  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s   38.0  Masculino       35-39
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt   39.0  Masculino       35-39
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh   30.0  Masculino       30-34
# 3     v31ab41botodnsv31zgg4k34zzojy81l   38.0   Feminino       35-39
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k   36.0  Masculino       35-39
# ...                                ...    ...        ...         ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg   40.0  Masculino       40-44
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg   27.0  Masculino       25-29
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18   24.0  Masculino       22-24
# 2643  075h3v2z19if04yn7o075h3vhifl38rw   38.0  Masculino       35-39
# 2644  037usz1h2yip96dgil4mhj037uszw1gk   27.0   Feminino       25-29
#
#          Estado_onde_mora uf_onde_mora             Nivel_de_Ensino  \
# 0              Ceará (CE)           CE               Pós-graduação
# ...

# %%
csv_file = '../datasets/com-tratamento/df_data_2021.csv'

# Salvando o DataFrame tratado em um arquivo CSV
df_data_2021.to_csv(csv_file, index=False)

# %% [markdown]
# ## Parte 2 - Dataset State of Data 2022

# %%
# prompt: leia o arquivo state_of_data_2022.csv para um dataframe

df_data_22 = pd.read_csv('../datasets/sem-tratamento/State_of_data_2022.csv')

def renameColumn(column):
    parts = column.split('\'')
    return parts[3]

df_data_22.columns = df_data_22.columns.map(renameColumn)

df_data_22.head()
# Out:
#                                  id  Idade Faixa idade     Genero  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   Cor/raca/etnia  PCD               experiencia_profissional_prejudicada  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           aspectos_prejudicados  vive_no_brasil  \
# ...

# %%
num_colunas = df_data_22.shape[1]

# Exibir a quantidade de colunas
print(f'Quantidade de colunas: {num_colunas}')
# Out:
# Quantidade de colunas: 353

# %%
df_data_22.columns.tolist()
# Out:
# ['id',
#  'Idade',
#  'Faixa idade',
#  'Genero',
#  'Cor/raca/etnia',
#  'PCD',
#  'experiencia_profissional_prejudicada',
#  'aspectos_prejudicados',
#  'vive_no_brasil',
#  'Estado onde mora',
#  'uf onde mora',
#  'Regiao onde mora',
#  'Mudou de Estado?',
#  'Regiao de origem',
#  'Nivel de Ensino',
#  'Área de Formação',
#  'Qual sua situação atual de trabalho?',
#  'Setor',
#  'Numero de Funcionarios',
#  'Gestor?',
#  'Cargo como Gestor',
#  'Cargo Atual',
#  'Nivel',
#  'Faixa salarial',
#  'Quanto tempo de experiência na área de dados você tem?',
#  'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
#  'Você está satisfeito na sua empresa atual?',
#  'Qual o principal motivo da sua insatisfação com a empresa atual?',
#  'Falta de oportunidade de crescimento no emprego atual',
#  'Salário atual não corresponde ao mercado',
#  'Não tenho uma boa relação com meu líder/gestor',
# ...

# %%
# Listar as colunas que você deseja extrair
colunas_desejadas = ['id',
                      'Idade',
                      'Faixa idade',
                      'Genero',
                      'Cor/raca/etnia',
                      'PCD',
                      'experiencia_profissional_prejudicada',
                      'aspectos_prejudicados',
                      'vive_no_brasil',
                      'Estado onde mora',
                      'uf onde mora',
                      'Regiao onde mora',
                      'Nivel de Ensino',
                      'Área de Formação',
                      'Cargo Atual',
                      'Nivel',
                      'Faixa salarial']

# Criar um novo DataFrame com as colunas desejadas
df_novo_2022 = df_data_22[colunas_desejadas]

# Salvar o novo DataFrame como um arquivo CSV
df_novo_2022.to_csv('../datasets/com-tratamento/df_data_2022.csv', index=False)

# Exibir o novo DataFrame para confirmar
print(df_novo_2022.head())
# Out:
#                                  id  Idade Faixa idade     Genero  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   Cor/raca/etnia  PCD               experiencia_profissional_prejudicada  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           aspectos_prejudicados  vive_no_brasil  \
# ...

# %% [markdown]
# ## Parte 3 - Dataset State of Data 2023

# %%
#importando pasta do drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importnado dataset

df_data_23 = pd.read_csv('../datasets/sem-tratamento/State_of_data_2023.csv')

df_data_23.head()
# Out:
#                        ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1  0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3  00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9                  34
#
#   ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero') ('P1_c ', 'Cor/raca/etnia')  \
# 0                      30-34           Masculino                      Branca
# 1                      30-34           Masculino                      Branca
# 2                      35-39            Feminino                     Amarela
# 3                      22-24           Masculino                       Preta
# 4                      30-34           Masculino                      Branca
#
#   ('P1_d ', 'PCD')  ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0              Não                                                NaN
# ...

# %%
#excluindo espaços nos nomes das colunas e adicionando '_' no local

def renameColumn(column):
    parts = column.split('\'')
    parts[3] = parts[3].replace(' ', '_')
    parts[3] = parts[3].replace('?', '')
    return parts[3]

df_data_23.columns = df_data_23.columns.map(renameColumn)

df_data_23.head()
# Out:
#                                  id  Idade Faixa_idade     Genero  \
# 0  001b2d1qtli8t9z7oqgdhj001b2d4i0g     31       30-34  Masculino
# 1  0026aa3fwd78u0026asg7456tfkjg2cs     30       30-34  Masculino
# 2  00r21rb9pusd1b0v7ew00r21rw3dy69w     37       35-39   Feminino
# 3  00urm3jf2cek12w6ygue00urm3jzd17j     22       22-24  Masculino
# 4  00v0az4g792svil00vn6y1kfm9hq8vy9     34       30-34  Masculino
#
#   Cor/raca/etnia  PCD               experiencia_profissional_prejudicada  \
# 0         Branca  Não                                                NaN
# 1         Branca  Não                                                NaN
# 2        Amarela  Não  Sim, acredito que a minha a experiência profis...
# 3          Preta  Não  Não acredito que minha experiência profissiona...
# 4         Branca  Não                                                NaN
#
#    Não_acredito_que_minha_experiência_profissional_seja_afetada  \
# 0                                                NaN
# ...

# %%
#visulizando o nome de todas as colunas
for column in df_data_23.columns:
    print(column)
# Out:
# id
# Idade
# Faixa_idade
# Genero
# Cor/raca/etnia
# PCD
# experiencia_profissional_prejudicada
# Não_acredito_que_minha_experiência_profissional_seja_afetada
# Experiencia_prejudicada_devido_a_minha_Cor_Raça_Etnia
# Experiencia_prejudicada_devido_a_minha_identidade_de_gênero
# Experiencia_prejudicada_devido_ao_fato_de_ser_PCD
# aspectos_prejudicados
# Quantidade_de_oportunidades_de_emprego/vagas_recebidas
# Senioridade_das_vagas_recebidas_em_relação_à_sua_experiência
# Aprovação_em_processos_seletivos/entrevistas
# Oportunidades_de_progressão_de_carreira
# Velocidade_de_progressão_de_carreira
# Nível_de_cobrança_no_trabalho/Stress_no_trabalho
# Atenção_dada_diante_das_minhas_opiniões_e_ideias
# Relação_com_outros_membros_da_empresa,_em_momentos_de_trabalho
# Relação_com_outros_membros_da_empresa,_em_momentos_de_integração_e_outros_momentos_fora_do_trabalho
# vive_no_brasil
# Estado_onde_mora
# uf_onde_mora
# Regiao_onde_mora
# Mudou_de_Estado
# Regiao_de_origem
# Nivel_de_Ensino
# ...

# %%
#selecionando as colunas de uso
columns_to_use = [
    'id',
    'Idade',
    'Genero',
    'Cor/raca/etnia',
    'PCD',
    'Faixa_idade',
    'experiencia_profissional_prejudicada',
    'Não_acredito_que_minha_experiência_profissional_seja_afetada',
    'Experiencia_prejudicada_devido_a_minha_Cor_Raça_Etnia',
    'Experiencia_prejudicada_devido_a_minha_identidade_de_gênero',
    'Experiencia_prejudicada_devido_ao_fato_de_ser_PCD',
    'Qual_sua_situação_atual_de_trabalho',
    'vive_no_brasil',
    'uf_onde_mora',
    'Regiao_onde_mora',
    'Nivel_de_Ensino',
    'Cargo_Atual',
    'Nivel',
    'Faixa_salarial',

]

# %%
# Exibe o novo DataFrame com as colunas selecionadas

df_novo_2023 = df_data_23[columns_to_use]
print(df_novo_2023)
# Out:
#                                     id  Idade     Genero Cor/raca/etnia  PCD  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g     31  Masculino         Branca  Não
# 1     0026aa3fwd78u0026asg7456tfkjg2cs     30  Masculino         Branca  Não
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w     37   Feminino        Amarela  Não
# 3     00urm3jf2cek12w6ygue00urm3jzd17j     22  Masculino          Preta  Não
# 4     00v0az4g792svil00vn6y1kfm9hq8vy9     34  Masculino         Branca  Não
# ...                                ...    ...        ...            ...  ...
# 5288  zyg9519671iqrgy93qzyg95183k8ix5f     34  Masculino          Preta  Não
# 5289  zyppgxzxko25qkgwsbrgpzyppgxzxs81     32  Masculino         Branca  Não
# 5290  zysl5f50cnz3r0cbe6t2zysrxbzfsrng     25  Masculino         Branca  Não
# 5291  zyt2656c9e1becxp457zyt26566dsng8     31  Masculino          Parda  Não
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x     31  Masculino        Amarela  Não
#
# ...

# %%
#visualizando colunas selecionadas
df_novo_2023.columns
# Out:
# Index(['id', 'Idade', 'Genero', 'Cor/raca/etnia', 'PCD', 'Faixa_idade',
#        'experiencia_profissional_prejudicada',
#        'Não_acredito_que_minha_experiência_profissional_seja_afetada',
#        'Experiencia_prejudicada_devido_a_minha_Cor_Raça_Etnia',
#        'Experiencia_prejudicada_devido_a_minha_identidade_de_gênero',
#        'Experiencia_prejudicada_devido_ao_fato_de_ser_PCD',
#        'Qual_sua_situação_atual_de_trabalho', 'vive_no_brasil', 'uf_onde_mora',
#        'Regiao_onde_mora', 'Nivel_de_Ensino', 'Cargo_Atual', 'Nivel',
#        'Faixa_salarial'],
#       dtype='object')

# %%
csv_file = '../datasets/com-tratamento/df_data_2023.csv'

# Salvando o DataFrame tratado em um arquivo CSV
df_novo_2023.to_csv(csv_file, index=False)

# %% [markdown]
# ## Visualizações

# %%
# Criando tabela cruzada para gênero e faixa salarial
abs_genero = pd.crosstab(df_novo_2023["Faixa_salarial"], df_novo_2023["Genero"])

# Preparando dados para o gráfico
women_pop = list(abs_genero["Feminino"])
men_pop = [-1 * element for element in abs_genero["Masculino"]]  # Multiplicar por -1 para criar a pirâmide

faixa = list(abs_genero.index.values)

# Criando a figura do gráfico
fig = go.Figure()

# Adicionando barras para a população masculina
fig.add_trace(go.Bar(
    y=faixa,
    x=men_pop,
    name='Masculino',
    marker_color='lightgray',
    orientation='h'
))

# Adicionando barras para a população feminina
fig.add_trace(go.Bar(
    y=faixa,
    x=women_pop,
    name='Feminino',
    marker_color='#710c04',
    orientation='h'
))

# Atualizando o layout do gráfico
fig.update_layout(
    title="Pirâmide salarial segundo o gênero",
    yaxis_title='Faixa salarial',
    xaxis_title='Número de pessoas',
    barmode='relative',
    xaxis_tickangle=-90,
    plot_bgcolor='rgba(0,0,0,0)',
    width=800,
    height=500,
    legend=dict(title='Gênero')
)

# Exibindo o gráfico
fig.show()
